# %%
import requests

# %%
req = requests.get('https://lintangwisesa.github.io/Indonesia-Covid19-Maps/data/provinsi/all.json')

# %%
data = req.json()

# %%
print(len(data))
# Out:
# 34

# %%
import pandas as pd

# %%
test = pd.DataFrame(data)

# %%
test
# Out:
#               Provinsi  Confirmed  Recovered  Deaths  Active cases  \
# 0                 Aceh          5          4       1             0
# 1                 Bali         98         23       2            73
# 2      Bangka Belitung          5          0       1             4
# 3               Banten        281          7      25           249
# 4             Bengkulu          4          0       1             3
# 5         Central Java        292         19      27           246
# 6   Central Kalimantan         33          8       2            23
# 7     Central Sulawesi         22          2       3            17
# 8            East Java        499         81      45           373
# 9      East Kalimantan         35          6       1            28
# 10  East Nusa Tenggara          1          0       0             1
# 11           Gorontalo          1          0       0             1
# 12             Jakarta       2474        164     242          2068
# ...

# %%
test.to_csv('Indonesia_provinsi.csv', index=False)

# %%
print(indonesia)
# Out:
# 1

# %%
indonesia = dunia[dunia['country']=='Indonesia']

# %%
indonesia
# Out:
#       country  cases  todayCases  deaths  todayDeaths  recovered  active  \
# 43  Indonesia   5136         297     469           10      446.0    4221
#
#     critical  casesPerOneMillion  deathsPerOneMillion  totalTests  \
# 43         0                  19                    2       36000
#
#     testsPerOneMillion
# 43                 132

# %%
indonesia.to_csv('Indonesia.csv', index=False)
